# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %% [markdown]
# ## Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %% [markdown]
# ## Preparando a Conexão com o Twitter

# %%
# Instala o pacote tweepy
# !pip install tweepy

# %%
# !pip install pymongo

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no manual em pdf como criar sua API no Twitter e configure as suas chaves abaixo.

# %%
# Adicione aqui sua Consumer Key
consumer_key = "iwn3nirS6jkFnCmY6WXLJz9cu"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret = "bfFKzRwHYdjaGKqbwVY1XX413WJvNSzEaJ0bUE5R8C862SZNKx"

# %%
# Adicione aqui seu Access Token
access_token = "1085894290964955139-sEGSfiZRDEJ0ceBDkEqm8JDUX5BCnV"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "9xaRSEp5fVQTtYfmNiRyS0pZqi7X7yCrVVc1hXuxYLaSh"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ## Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Bolsonaro']

# %% [markdown]
# ## Coletando os Tweets

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Thu Jan 17 16:01:43 +0000 2019', 'id_str': '1085930172082200579', 'text': 'RT @GuilhermeBoulos: STF acaba de suspender a investigação de Queiroz a pedido de Flávio Bolsonaro. O cabo e o soldado já entraram no STF?', '_id': ObjectId('5c40a6ecf912df3d35f2efa1')}
# {'created_at': 'Thu Jan 17 16:01:43 +0000 2019', 'id_str': '1085930172266790912', 'text': 'Próximo atentado, 2022 🤣🤣🤣🤣🤣🤣, o gado acredita. https://t.co/kIUXyKS4NB', '_id': ObjectId('5c40a6ecf912df3d35f2efa2')}
# {'created_at': 'Thu Jan 17 16:01:43 +0000 2019', 'id_str': '1085930172598095872', 'text': 'RT @cobaintyles: e o Nirvana que em 1991 previu o rockeiro conservador que passou a vida ouvindo músicas de críticas sociais sem entender e…', '_id': ObjectId('5c40a6ecf912df3d35f2efa3')}
# {'created_at': 'Thu Jan 17 16:01:43 +0000 2019', 'id_str': '1085930172702961666', 'text': '@jojojaoo @FeCastanhari e daí o que ? Foi uma duvida apenas, ele responde se quiser uai. Meu pensamento quanto a ju… https://t.co/vZWmaoLU7Q', '_id': ObjectId('5c40a6ecf912df3d35f2efa4')}
# {'created_at': 'Thu Jan 17 16:01:43 +0000 2019', 'id_str': '1085
}
# {'created_at': 'Thu Jan 17 16:01:47 +0000 2019', 'id_str': '1085930189740298240', 'text': 'RT @allantercalivre: A internet não perdoa. https://t.co/1ghL8AuBpl', '_id': ObjectId('5c40a6f0f912df3d35f2efe0')}
# {'created_at': 'Thu Jan 17 16:01:47 +0000 2019', 'id_str': '1085930190058991616', 'text': 'RT @Haddad_Fernando: O Jr. deu uma fraquejada: Flávio Bolsonaro pede, e STF suspende investigação sobre Queiroz https://t.co/fd5fqKYVQh via…', '_id': ObjectId('5c40a6f0f912df3d35f2efe1')}
# {'created_at': 'Thu Jan 17 16:01:47 +0000 2019', 'id_str': '1085930190285492225', 'text': 'RT @marpimenta: Podemos entender então que as investigações chegaram até o @FlavioBolsonaro ? Porque até então ele não era. https://t.co/C9…', '_id': ObjectId('5c40a6f0f912df3d35f2efe2')}
# {'created_at': 'Thu Jan 17 16:01:47 +0000 2019', 'id_str': '1085930190918815744', 'text': 'RT @GDimenstein: Nesse caso em especial, a maconha talvez tivesse um efeito medicinal\n\nhttps://t.co/cR20TDFrbL', '_id': ObjectId('5c40a6f0f912df3d35f2efe3')}
# {'created_at': 'Thu Jan 17 16:01:47 +0000 2019', 'id_str': '1085930191023681537', 'text': 'RT @CavaleiroTemplo: CARLA ZAMBELLI FALANDO MAL DO BOLSONARO https://t.co/HbOdeN1EoZ', '_id': ObjectId('5c40a6f0f912df3d35f2efe4')}
# {'created_at': 'Thu Jan 17 16:01:47 +0000 2019', 'id_str': '1085930191669600257', 'text': 'bem aliviada de saber que meu professor que foi meu orientador durante 3 anos é contra Bolsonaro', '_id': ObjectId('5c40a6f1f912df3d35f2efe5')}
# {'created_at': 'Thu Jan 17 16:01:47 +0000 2019', 'id_str': '1085930191564746752', 'text': 'Como que fala? "COM O SUPREMO COM TUDO"? E você caro bozominion, achou que o "Mito" e sua famiglia eram contra a co… https://t.co/g3ZsTcAIO3', '_id': ObjectId('5c40a6f1f912df3d35f2efe6')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930192080683010', 'text': '@lindberghfarias Família Bolsonaro especialistas em apontar dedo e denunciar corrupção.  Olhem o que está acontecen… https://t.co/3qyk2G06Do', '_id': ObjectId('5c40a6f1f912df3d35f2efe7')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930192596545536', 'text': 'RT @felipeneto: Acabou de sair no Lauro Jardim.\n\nO pedido de suspensão da investigação do Queiroz veio do PRÓPRIO FLÁVIO BOLSONARO.\n\nMano v…', '_id': ObjectId('5c40a6f1f912df3d35f2efe8')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930192378441728', 'text': 'RT @breakzplatform: Bumbum como é bom ser lelé\nBumbum como é bom ser lelé\nRir com histórias brincar sem parar\nBumbum como é bom ser lelé ht…', '_id': ObjectId('5c40a6f1f912df3d35f2efe9')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930193020207116', 'text': 'RT @ernestofaraujo: O Itamaraty teve hoje a honra de sediar o almoço que o Pres. Bolsonaro ofereceu ao Pres. Macri na primeira visita de um…', '_id': ObjectId('5c40a6f1f912df3d35f2efea')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930193544458240', 'text': 'Então...', '_id': ObjectId('5c40a6f1f912df3d35f2efeb')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930193552793600', 'text': 'RT @JliaAnd90009545: #SeEleEstivesseArmado  Como vocês podem ser contra um decreto que vai trazer proteção pras famílias só por causa de se…', '_id': ObjectId('5c40a6f1f912df3d35f2efec')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930193586401280', 'text': 'Flávio Bolsonaro pede, e STF suspende investigação sobre Queiroz https://t.co/Y4JVccHm3E via @UOLNoticias @UOL', '_id': ObjectId('5c40a6f1f912df3d35f2efed')}
# {'created_at': 'Thu Jan 17 16:01:48 +0000 2019', 'id_str': '1085930195872305152', 'text': 'RT @CavaleiroTemplo: CARLA ZAMBELLI FALANDO MAL DO BOLSONARO https://t.co/HbOdeN1EoZ', '_id': ObjectId('5c40a6f2f912df3d35f2efee')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930196488912897', 'text': 'Ninguém dá conta dessa tarefa sozinho', '_id': ObjectId('5c40a6f2f912df3d35f2efef')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930197248032768', 'text': 'RT @eurenesilva: RINDO DOS QUE VOTARAM POR UM BRASIL SEM CORRUPÇÃO https://t.co/feLH1vtYAa', '_id': ObjectId('5c40a6f2f912df3d35f2eff0')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930198091120646', 'text': 'RT @helenateua: Acontece que o foro adequado para atos cometidos antes da diplomação do senador não é o STF, segundo decidiu o pleno do pró…', '_id': ObjectId('5c40a6f2f912df3d35f2eff1')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930198489538560', 'text': 'kkkkkkkkkkkkkkkkkkkkk q Deus abençoe essa cadelinha chamada nação brasileira', '_id': ObjectId('5c40a6f2f912df3d35f2eff2')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930198653173765', 'text': 'RT @felipeneto: Sabe o que é mais assustador?\n\nAlgumas pessoas ficaram tão bitoladas, tão alucinadas pelo Bolsonaro e tão desesperadas pra…', '_id': ObjectId('5c40a6f2f912df3d35f2eff3')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930199026462722', 'text': 'RT @ramos_leandro: Divulgar aqui uma grande vitória pessoal. Em vez de responder meus tuítes e debater comigo, o pilantra do Flavio Bolsona…', '_id': ObjectId('5c40a6f2f912df3d35f2eff4')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930199097716737', 'text': 'https://t.co/fklgMCB52j', '_id': ObjectId('5c40a6f2f912df3d35f2eff5')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930199227740162', 'text': 'Luiz Fux manda suspender investigação do escândalo Queiroz-Bolsonaro https://t.co/hNRpmrT4P4  O que esterar desse pseudo juíz?', '_id': ObjectId('5c40a6f2f912df3d35f2eff6')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930199303172097', 'text': 'RT @felipeneto: Acabou de sair no Lauro Jardim.\n\nO pedido de suspensão da investigação do Queiroz veio do PRÓPRIO FLÁVIO BOLSONARO.\n\nMano v…', '_id': ObjectId('5c40a6f2f912df3d35f2eff7')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930199630442496', 'text': '@_rodrigomattos_ Ahhh, mas agora eu quero que a investigação continue. Votei no Bolsonaro e não tenho pena de ladrão!', '_id': ObjectId('5c40a6f3f912df3d35f2eff8')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930199353577472', 'text': 'Que porra é essa @jairbolsonaro @FlavioBolsonaro ???\nJaja vamos ter que meter o general mesmo !\n@GeneralMourao', '_id': ObjectId('5c40a6f3f912df3d35f2eff9')}
# {'created_at': 'Thu Jan 17 16:01:49 +0000 2019', 'id_str': '1085930199798157313', 'text': 'RT @JornalOGlobo: Suspensão de investigação do caso Queiroz foi pedida por Flávio Bolsonaro. https://t.co/OdzoZOq6zU', '_id': ObjectId('5c40a6f3f912df3d35f2effa')}
# {'created_at': 'Thu Jan 17 16:01:50 +0000 2019', 'id_str': '1085
}
# {'created_at': 'Thu Jan 17 16:01:51 +0000 2019', 'id_str': '1085930208467845121', 'text': 'PensarAmericas: RT AmbassadorCuba: Esos son los #DDHH que quieren imponerle a #Cuba #Venezuela #Nicaragua #Bolivia… https://t.co/VLFGyPwoib', '_id': ObjectId('5c40a6f5f912df3d35f2f016')}
# {'created_at': 'Thu Jan 17 16:01:51 +0000 2019', 'id_str': '1085930208555909126', 'text': 'RT @tbronzatto: O pedido de suspensão da investigação foi feito pelo senador eleito @FlavioBolsonaro https://t.co/sW6EMuWvVH', '_id': ObjectId('5c40a6f5f912df3d35f2f017')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930208711065601', 'text': 'RT @adrielsentinela: Luiz Fux (STF) suspender a investigação sobre Queiroz não é motivo de comemoração!\nBolsonaro foi eleito com o discurso…', '_id': ObjectId('5c40a6f5f912df3d35f2f018')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930209038221312', 'text': 'RT @jeferson: STF parando as investigações contra o Queiroz a pedido do Flávio Bolsonaro que se recusou a depor ao MP-RJ.\n\nFico me pergunta…', '_id': ObjectId('5c40a6f5f912df3d35f2f019')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930210141315073', 'text': 'RT @jeferson: STF parando as investigações contra o Queiroz a pedido do Flávio Bolsonaro que se recusou a depor ao MP-RJ.\n\nFico me pergunta…', '_id': ObjectId('5c40a6f5f912df3d35f2f01a')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930210871136256', 'text': 'Flávio bolsonaro Otimismo com o que??? Que nada!! Com o apoio ao Rodrigo Maia??? Cadê o laranja Queiroz??? Qual a m… https://t.co/cSxAcgoEBY', '_id': ObjectId('5c40a6f5f912df3d35f2f01b')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930212402102274', 'text': 'UEEEEEEEEEEEEEEEEEEEEEE', '_id': ObjectId('5c40a6f6f912df3d35f2f01c')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930212620156930', 'text': 'RT @felipeneto: Antigamente a corrupção acabava sempre em pizza.\n\nFamília Bolsonaro ACABOU COM ISSO DE UMA VEZ!\n\nAgora a corrupção acaba co…', '_id': ObjectId('5c40a6f6f912df3d35f2f01d')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930212603453441', 'text': 'RT @rcp01: Negociações com à China comunista deve ser feitas pelo Presidente Jair Bolsonaro e seu alto escalão. Não por amadores deslumbrad…', '_id': ObjectId('5c40a6f6f912df3d35f2f01e')}
# {'created_at': 'Thu Jan 17 16:01:52 +0000 2019', 'id_str': '1085930212666368000', 'text': 'RT @DaniloGentili: Justiça no Brasil é igual cobra em festa junina “Óia as coisas diferente finalmente chegando... era mentiraaaaa” https:/…', '_id': ObjectId('5c40a6f6f912df3d35f2f01f')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930214373371904', 'text': 'RT @GuilhermeBoulos: STF acaba de suspender a investigação de Queiroz a pedido de Flávio Bolsonaro. O cabo e o soldado já entraram no STF?', '_id': ObjectId('5c40a6f6f912df3d35f2f020')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930215019368448', 'text': 'RT @bslvra: "STF suspende investigação sobre Queiroz; pedido de suspensão da investigação foi feito por Flavio Bolsonaro"\nhttps://t.co/QZbg…', '_id': ObjectId('5c40a6f6f912df3d35f2f021')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930214851600384', 'text': 'RT @allantercalivre: @JornalOGlobo O jornalismo brasileiro coloca o décimo sétimo da lista e oculta o presidente da ALERJ, que curiosamente…', '_id': ObjectId('5c40a6f6f912df3d35f2f022')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930215770079233', 'text': 'RT @JotaInfo: Em sua decisão, Luiz Fux entendeu que, como Flavio Bolsonaro é senador eleito, o que faz com que passe a ter foro no STF a pa…', '_id': ObjectId('5c40a6f6f912df3d35f2f023')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930215791124480', 'text': 'RT @allantercalivre: A internet não perdoa. https://t.co/1ghL8AuBpl', '_id': ObjectId('5c40a6f6f912df3d35f2f024')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930216420265984', 'text': 'RT @DaniloGentili: Justiça no Brasil é igual cobra em festa junina “Óia as coisas diferente finalmente chegando... era mentiraaaaa” https:/…', '_id': ObjectId('5c40a6f7f912df3d35f2f025')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930216793522177', 'text': 'RT @rehventura: A mamata acabou\nChega de corrupção\nAgora é a nova era\nMuda, Brasil https://t.co/EcFpNwY9Ze', '_id': ObjectId('5c40a6f7f912df3d35f2f026')}
# {'created_at': 'Thu Jan 17 16:01:53 +0000 2019', 'id_str': '1085930216428572672', 'text': 'RT @DaniloGentili: Mas a Mamata não ia acabar?\nUé? https://t.co/wb6LvB7vaU', '_id': ObjectId('5c40a6f7f912df3d35f2f027')}
# {'created_at': 'Thu Jan 17 16:01:54 +0000 2019', 'id_str': '1085930217825292288', 'text': 'RT @sound3vision: ALO VOCE\nQUE VOTOU NO BOLSONARO\nQUE BRIGOU COM AMIGOS E FAMILIA, QUE VESTIU CAMISA DA SELEÇAO\nQUE BATEU PANELA\nQUE DEFEND…', '_id': ObjectId('5c40a6f7f912df3d35f2f028')}
# {'created_at': 'Thu Jan 17 16:01:54 +0000 2019', 'id_str': '1085930217942773763', 'text': 'RT @felipeneto: Antigamente a corrupção acabava sempre em pizza.\n\nFamília Bolsonaro ACABOU COM ISSO DE UMA VEZ!\n\nAgora a corrupção acaba co…', '_id': ObjectId('5c40a6f7f912df3d35f2f029')}
# {'created_at': 'Thu Jan 17 16:01:54 +0000 2019', 'id_str': '1085930218194386945', 'text': 'RT @Haddad_Fernando: O Jr. deu uma fraquejada: Flávio Bolsonaro pede, e STF suspende investigação sobre Queiroz https://t.co/fd5fqKYVQh via…', '_id': ObjectId('5c40a6f7f912df3d35f2f02a')}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6a9070444200> in <module>
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# ## --> Pressione o botão Stop na barra de ferramentas para encerrar a captura dos Tweets

# %% [markdown]
# ## Consultando os Dados no MongoDB

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5c409daaf912df38bf7dc27b'),
#  'created_at': 'Thu Jan 17 15:22:13 +0000 2019',
#  'id_str': '1085920230847721479',
#  'text': 'Create a Keylogger with Python - Tutorial\n https://t.co/aEI4NEeRx6 #Vuejs #Javascript #nodejs #vue #AndroidDev… https://t.co/cnXYLxe0np'}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                          created_at  \
# 0    Thu Jan 17 15:22:13 +0000 2019
# 1    Thu Jan 17 15:22:14 +0000 2019
# 2    Thu Jan 17 15:22:16 +0000 2019
# 3    Thu Jan 17 15:22:18 +0000 2019
# 4    Thu Jan 17 15:22:17 +0000 2019
# 5    Thu Jan 17 15:22:18 +0000 2019
# 6    Thu Jan 17 15:22:18 +0000 2019
# 7    Thu Jan 17 15:22:21 +0000 2019
# 8    Thu Jan 17 15:22:24 +0000 2019
# 9    Thu Jan 17 15:22:24 +0000 2019
# 10   Thu Jan 17 15:22:25 +0000 2019
# 11   Thu Jan 17 15:22:26 +0000 2019
# 12   Thu Jan 17 15:22:26 +0000 2019
# 13   Thu Jan 17 15:22:26 +0000 2019
# 14   Thu Jan 17 15:22:28 +0000 2019
# 15   Thu Jan 17 15:22:28 +0000 2019
# 16   Thu Jan 17 15:22:30 +0000 2019
# 17   Thu Jan 17 15:22:31 +0000 2019
# 18   Thu Jan 17 15:22:34 +0000 2019
# 19   Thu Jan 17 15:22:35 +0000 2019
# 20   Thu Jan 17 15:22:36 +0000 2019
# 21   Thu Jan 17 15:22:37 +0000 2019
# 22   Thu Jan 17 15:22:37 +0000 2019
# 23   Thu Jan 17 15:22:38 +0000 2019
# 24   Thu Jan 17 15:22:38 +0000 2019
# 25   Thu Jan 17 15:22:40 +0000 2019
# 26   Thu Jan 17 15:22:40 +0000 2019
# 27   Thu Jan 17 15:22:43 +0000 2019
# 28   Thu Jan 17 16:01:43 +0000 2019
# 29   Thu Jan 17 16:01:43 +0000 2019
# ..                              ...
# 136  Thu Jan 17 16:01:51 +0000 2019
# 137  Thu Jan 17 16:01:51 +0000 2019
# 138  Thu Jan 17 16:01:51 +0000 2019
# 139  Thu Jan 17 16:01:51 +0000 2019
# 140  Thu Jan 17 16:01:51 +0000 2019
# 141  Thu Jan 17 16:01:51 +0000 2019
# 142  Thu Jan 17 16:01:51 +0000 2019
# 143  Thu Jan 17 16:01:51 +0000 2019
# 144  Thu Jan 17 16:01:51 +0000 2019
# 145  Thu Jan 17 16:01:51 +0000 2019
# 146  Thu Jan 17 16:01:51 +0000 2019
# 147  Thu Jan 17 16:01:52 +0000 2019
# 148  Thu Jan 17 16:01:52 +0000 2019
# 149  Thu Jan 17 16:01:52 +0000 2019
# 150  Thu Jan 17 16:01:52 +0000 2019
# 151  Thu Jan 17 16:01:52 +0000 2019
# 152  Thu Jan 17 16:01:52 +0000 2019
# 153  Thu Jan 17 16:01:52 +0000 2019
# 154  Thu Jan 17 16:01:52 +0000 2019
# 155  Thu Jan 17 16:01:53 +0000 2019
# 156  Thu Jan 17 16:01:53 +0000 2019
# 157  Thu Jan 17 16:01:53 +0000 2019
# 158  Thu Jan 17 16:01:53 +0000 2019
# 159  Thu Jan 17 16:01:53 +0000 2019
# 160  Thu Jan 17 16:01:53 +0000 2019
# 161  Thu Jan 17 16:01:53 +0000 2019
# 162  Thu Jan 17 16:01:53 +0000 2019
# 163  Thu Jan 17 16:01:54 +0000 2019
# 164  Thu Jan 17 16:01:54 +0000 2019
# 165  Thu Jan 17 16:01:54 +0000 2019
#
#                                                   text
# 0    Create a Keylogger with Python - Tutorial\n ht...
# 1    RT @BambamClothes: #BAMBAM #SAINTLAURENT\nStud...
# 2    RT @AnalyticsVidhya: (1/2) #AudioProcessing ha...
# 3                         I didn't know this. Amazing!
# 4    High value big data use cases https://t.co/PIt...
# 5    RT @iC0dE_: IF (You CODE &amp;&amp; Want to Be...
# 6    RT @funmioyatogun: This is how my Twitter grew...
# 7    RT @iC0dE_: Want to Write PROGRAMMING TUTORIAL...
# 8    RT @DesignObserver: 1969 was a hell of a year....
# 9    RT @pycoders: How to Write Beautiful Python Co...
# 10   RT @iC0dE_: WANT TO WRITE A PROGRAMMING TUTORI...
# 11   @zoltero The oppressometer is probably not tha...
# 12   RT @ymouscaz: I just discovered this excellent...
# 13   RT @InsurebrokersEs: Big Data y seguros: la re...
# 14   RT @iC0dE_: IF (You CODE &amp;&amp; Want to Be...
# 15   RT @sirajraval: My next 12 week course is call...
# 16   With the ability to crowdsource data and incen...
# 17   RT @iC0dE_: The First Issue of iC0dE Is Coming...
# 18   RT @iC0dE_: Would You like to Practice the Jav...
# 19   RT @anvil_works: Check out this Anvil guide fr...
# 20   Ontology and Data Science https://t.co/3Rg1x9Q...
# 21   .@siri_notsiri tells you all about Palantir's ...
# 22   RT @iC0dE_: How to Become a VOLUNTEER WRITER =...
# 23   RT @BenjaminGani: From making sense of data to...
# 24   RT @BambamClothes: #BAMBAM #SAINTLAURENT\nStud...
# 25   RT @iC0dE_: Which Part Of Day Is The Most Prod...
# 26   Expert Panel on Big Data for Transforming Smal...
# 27   @DumoSirak We are all raw data sets (metadata)...
# 28   RT @GuilhermeBoulos: STF acaba de suspender a ...
# 29   Próximo atentado, 2022 🤣🤣🤣🤣🤣🤣, o gado acredita...
# ..                                                 ...
# 136  RT @GuilhermeBoulos: STF acaba de suspender a ...
# 137  RT @vuintrieri: Pré-foro privilegiado. Brasil ...
# 138  RT @RenatoBacon: Gostaria de antecipadamente d...
# 139  @JornalOGlobo O que tem de petista preocupado ...
# 140  RT @macsanto787: Se fosse na Venezuela,esta fo...
# 141  RT @rcp01: Negociações com à China comunista d...
# 142  RT @comunacritico: Enfim chegou o momento da d...
# 143  RT @comunacritico: Enfim chegou o momento da d...
# 144  Flávio Bolsonaro, O STF, Supremo e MP-RJ nos T...
# 145  PensarAmericas: RT AmbassadorCuba: Esos son lo...
# 146  RT @tbronzatto: O pedido de suspensão da inves...
# 147  RT @adrielsentinela: Luiz Fux (STF) suspender ...
# 148  RT @jeferson: STF parando as investigações con...
# 149  RT @jeferson: STF parando as investigações con...
# 150  Flávio bolsonaro Otimismo com o que??? Que nad...
# 151                            UEEEEEEEEEEEEEEEEEEEEEE
# 152  RT @felipeneto: Antigamente a corrupção acabav...
# 153  RT @rcp01: Negociações com à China comunista d...
# 154  RT @DaniloGentili: Justiça no Brasil é igual c...
# 155  RT @GuilhermeBoulos: STF acaba de suspender a ...
# 156  RT @bslvra: "STF suspende investigação sobre Q...
# 157  RT @allantercalivre: @JornalOGlobo O jornalism...
# 158  RT @JotaInfo: Em sua decisão, Luiz Fux entende...
# 159  RT @allantercalivre: A internet não perdoa. ht...
# 160  RT @DaniloGentili: Justiça no Brasil é igual c...
# 161  RT @rehventura: A mamata acabou\nChega de corr...
# 162  RT @DaniloGentili: Mas a Mamata não ia acabar?...
# 163  RT @sound3vision: ALO VOCE\nQUE VOTOU NO BOLSO...
# 164  RT @felipeneto: Antigamente a corrupção acabav...
# 165  RT @Haddad_Fernando: O Jr. deu uma fraquejada:...
#
# [166 rows x 2 columns]

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                word  count
# 0                rt    117
# 1                de     82
# 2         bolsonaro     81
# 3                co     80
# 4             https     79
# 5               que     61
# 6            flávio     42
# 7      investigação     41
# 8               stf     39
# 9           queiroz     39
# 10               do     38
# 11              não     31
# 12               da     27
# 13              com     24
# 14               no     23
# 15           pedido     20
# 16              por     19
# 17           acabou     17
# 18               to     16
# 19               em     16
# 20              uma     15
# 21        corrupção     15
# 22            sobre     14
# 23              foi     14
# 24        suspender     14
# 25        suspensão     13
# 26             data     12
# 27               as     12
# 28               já     12
# 29         suspende     12
# 30             como     11
# 31            acaba     11
# 32       presidente     10
# 33               se     10
# 34              the      9
# 35              fux      9
# 36           brasil      9
# 37  guilhermeboulos      9
# 38              and      8
# 39               is      8
# 40          soldado      8
# 41         entraram      8
# 42              for      8
# 43              era      8
# 44             cabo      8
# 45       felipeneto      8
# 46           ic0de_      8
# 47           mamata      8
# 48              tem      7
# 49               ao      7

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
